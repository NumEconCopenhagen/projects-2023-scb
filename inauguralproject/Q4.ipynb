# %%
# %load_ext autoreload
# %autoreload 2

import HouseholdSpecializationModel as HSM
import numpy as np
from scipy import optimize

# %matplotlib inline
import matplotlib.pyplot as plt # baseline module
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Predefine options for all plots
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"-"})
plt.rcParams.update({'font.size': 14})
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# start with illustration
konrad = HSM.HouseholdSpecializationModelClass()

solution = konrad.estimate()
print(solution)
# Out:
# in solve_wF_vec, HF_vec = [5.55061287 5.37261236 5.25910258 5.1853456  5.13512354]
# in run_regression, HF_vec: [5.55061287 5.37261236 5.25910258 5.1853456  5.13512354]
# alpha, sigma    = ((0.001, 12.0))
# min_function    = 0.1734794757838411
# beta0, beta1    = (0.0004684588852015433, -0.21770311566936185)
# in solve_wF_vec, HF_vec = [5.55061027 5.37261245 5.25910243 5.18534489 5.13512361]
# in run_regression, HF_vec: [5.55061027 5.37261245 5.25910243 5.18534489 5.13512361]
# alpha, sigma    = ((0.0010000149011611939, 12.0))
# min_function    = 0.17347923670766754
# beta0, beta1    = (0.0004685120196315473, -0.21770228043610804)
# in solve_wF_vec, HF_vec = [5.55061022 5.37261351 5.25910224 5.18534443 5.13512347]
# in run_regression, HF_vec: [5.55061022 5.37261351 5.25910224 5.18534443 5.13512347]
# alpha, sigma    = ((0.001, 12.000000014901161))
# min_function    = 0.173479323004958
# beta0, beta1    = (0.0004684458259789255, -0.21770242233806936)
# in solve_wF_vec, HF_vec = [ 1.          1.          1.         15.2727484  14.66666697]
# in run_regression, HF_vec: [ 1.          1.          1.         15.2727484  14.66666697]
# alpha, sigma    = ((0.9999999999994357, 22.252817288041115))
# min_function    = 0.3269402082224989
# beta0, beta1    = (-0.05999861936880709, -0.4396196083875168)
# in solve_wF_vec, HF_vec = [6.17105262 5.97092003 5.84170865 5.7561598  5.69671416]
# in run_regression, HF_vec: [6.17105262 5.97092003 5.84170865 5.7561598  5.69671416]
# alpha, sigma    = ((0.4998680750823803, 17.119923147807118))
# min_function    = 0.17624177823380605
# beta0, beta1    = (0.0004531909616462693, -0.2288569967874284)
# in solve_wF_vec, HF_vec = [5.80304363 5.61602653 5.49614689 5.41761676 5.36365198]
# in run_regression, HF_vec: [5.80304363 5.61602653 5.49614689 5.41761676 5.36365198]
# alpha, sigma    = ((0.25042264896600686, 14.559844692041171))
# min_function    = 0.17462073409082204
# beta0, beta1    = (0.00046371881533001694, -0.22243975705605745)
# in solve_wF_vec, HF_vec = [5.66720916 5.48505531 5.36861011 5.29265624 5.24070793]
# in run_regression, HF_vec: [5.66720916 5.48505531 5.36861011 5.29265624 5.24070793]
# alpha, sigma    = ((0.1257066192020579, 13.279874055344086))
# min_function    = 0.17400859749350905
# beta0, beta1    = (0.00046640054115618454, -0.21992289354818448)
# in solve_wF_vec, HF_vec = [5.60689134 5.42689125 5.31196454 5.23714737 5.18609393]
# in run_regression, HF_vec: [5.60689134 5.42689125 5.31196454 5.23714737 5.18609393]
# alpha, sigma    = ((0.06335112808514198, 12.63991463859917))
# min_function    = 0.17373528176670414
# beta0, beta1    = (0.0004675077333156524, -0.21878160375191072)
# in solve_wF_vec, HF_vec = [5.57828711 5.39930434 5.28509875 5.21081977 5.16018918]
# in run_regression, HF_vec: [5.57828711 5.39930434 5.28509875 5.21081977 5.16018918]
# alpha, sigma    = ((0.03217450937886919, 12.319946495201252))
# min_function    = 0.17360545256128632
# beta0, beta1    = (0.0004679211399236327, -0.21823523384774943)
# in solve_wF_vec, HF_vec = [5.56433736 5.38585013 5.27199608 5.19798032 5.14755572]
# in run_regression, HF_vec: [5.56433736 5.38585013 5.27199608 5.19798032 5.14755572]
# alpha, sigma    = ((0.016586735298916452, 12.159967917053995))
# min_function    = 0.17354175850211326
# beta0, beta1    = (0.0004682408274421767, -0.21796665594393405)
# in solve_wF_vec, HF_vec = [5.55744634 5.37920411 5.26552322 5.19163742 5.14131508]
# in run_regression, HF_vec: [5.55744634 5.37920411 5.26552322 5.19163742 5.14131508]
# alpha, sigma    = ((0.008793110863517108, 12.079981323112246))
# min_function    = 0.1735104917954035
# beta0, beta1    = (0.00046831309362452484, -0.21783430295609796)
# in solve_wF_vec, HF_vec = [5.55402159 5.37590186 5.26230716 5.18848561 5.13821327]
# in run_regression, HF_vec: [5.55402159 5.37590186 5.26230716 5.18848561 5.13821327]
# alpha, sigma    = ((0.004896427555567737, 12.0399893491525))
# min_function    = 0.173494909765895
# beta0, beta1    = (0.0004684232451041451, -0.21776853969393417)
# in solve_wF_vec, HF_vec = [5.55231506 5.37425502 5.26070354 5.18691251 5.13666657]
# in run_regression, HF_vec: [5.55231506 5.37425502 5.26070354 5.18691251 5.13666657]
# alpha, sigma    = ((0.0029481501448716456, 12.019994021506557))
# min_function    = 0.17348725633465176
# beta0, beta1    = (0.0004683840139385382, -0.21773590855052707)
# in solve_wF_vec, HF_vec = [5.55146198 5.37343233 5.25990304 5.18612794 5.13589487]
# in run_regression, HF_vec: [5.55146198 5.37343233 5.25990304 5.18612794 5.13589487]
# alpha, sigma    = ((0.0019740429939371354, 12.009996681529069))
# min_function    = 0.1734832232557537
# beta0, beta1    = (0.00046838568659666313, -0.21771878533131234)
# in solve_wF_vec, HF_vec = [5.55146255 5.37343405 5.25990262 5.18612907 5.13589422]
# in run_regression, HF_vec: [5.55146255 5.37343405 5.25990262 5.18612907 5.13589422]
# alpha, sigma    = ((0.001974057895098329, 12.009996681529069))
# min_function    = 0.17348322792583384
# beta0, beta1    = (0.00046845712090178693, -0.21771904761117095)
# in solve_wF_vec, HF_vec = [5.55146195 5.37343446 5.25990211 5.1861282  5.1358941 ]
# in run_regression, HF_vec: [5.55146195 5.37343446 5.25990211 5.1861282  5.1358941 ]
# alpha, sigma    = ((0.0019740429939371354, 12.00999669643023))
# min_function    = 0.1734832189223727
# beta0, beta1    = (0.0004684825591938129, -0.2177190957059195)
# in solve_wF_vec, HF_vec = [5.54973749 5.37177075 5.25828257 5.18454061 5.13433216]
# in run_regression, HF_vec: [5.54973749 5.37177075 5.25828257 5.18454061 5.13433216]
# alpha, sigma    = ((1.0000000045910784e-08, 12.013576274778208))
# min_function    = 0.17347543905149043
# beta0, beta1    = (0.00046846988867050996, -0.21768600383388934)
# in solve_wF_vec, HF_vec = [5.55059359 5.37259725 5.2590885  5.18533063 5.13510866]
# in run_regression, HF_vec: [5.55059359 5.37259725 5.2590885  5.18533063 5.13510866]
# alpha, sigma    = ((0.0009823752943363452, 12.011794912366032))
# min_function    = 0.17347924576017035
# beta0, beta1    = (0.0004684227979506097, -0.21770201603461672)
# in solve_wF_vec, HF_vec = [5.5510266  5.3730141  5.25949412 5.18572718 5.13550046]
# in run_regression, HF_vec: [5.5510266  5.3730141  5.25949412 5.18572718 5.13550046]
# alpha, sigma    = ((0.001475832326636352, 12.01090010692611))
# min_function    = 0.17348127746137365
# beta0, beta1    = (0.00046842242533770025, -0.2177106451518944)
# in solve_wF_vec, HF_vec = [5.55124378 5.37322213 5.2596978  5.18592623 5.13569776]
# in run_regression, HF_vec: [5.55124378 5.37322213 5.2596978  5.18592623 5.13569776]
# alpha, sigma    = ((0.0017237750654292368, 12.010450502407501))
# min_function    = 0.173482190307075
# beta0, beta1    = (0.00046850016333175524, -0.217714786434574)
# in solve_wF_vec, HF_vec = [5.55135292 5.37332774 5.25979902 5.18602659 5.13579379]
# in run_regression, HF_vec: [5.55135292 5.37332774 5.25979902 5.18602659 5.13579379]
# alpha, sigma    = ((0.0018482916883945683, 12.010224711418019))
# min_function    = 0.17348288250000785
# beta0, beta1    = (0.0004684144777894367, -0.21771743570990826)
# in solve_wF_vec, HF_vec = [5.55140785 5.37338082 5.2598507  5.18607718 5.13584389]
# in run_regression, HF_vec: [5.55140785 5.37338082 5.2598507  5.18607718 5.13584389]
# alpha, sigma    = ((0.001910964033155168, 12.01011106514012))
# min_function    = 0.17348299699442507
# beta0, beta1    = (0.0004684826116797679, -0.21771815326368063)
# in solve_wF_vec, HF_vec = [5.55143416 5.3734073  5.25987671 5.18610271 5.13586874]
# in run_regression, HF_vec: [5.55143416 5.3734073  5.25987671 5.18610271 5.13586874]
# alpha, sigma    = ((0.0019423683758638482, 12.010054118385176))
# min_function    = 0.17348309935742937
# beta0, beta1    = (0.0004684299357566615, -0.21771840926307998)
# in solve_wF_vec, HF_vec = [5.55144869 5.37342085 5.25988787 5.18611582 5.1358819 ]
# in run_regression, HF_vec: [5.55144869 5.37342085 5.25988787 5.18611582 5.1358819 ]
# alpha, sigma    = ((0.0019581316562187825, 12.010025534196302))
# min_function    = 0.1734831373304954
# beta0, beta1    = (0.00046849431009064735, -0.21771878903407604)
# in solve_wF_vec, HF_vec = [5.55145559 5.37342748 5.25989479 5.18612225 5.13588845]
# in run_regression, HF_vec: [5.55145559 5.37342748 5.25989479 5.18612225 5.13588845]
# alpha, sigma    = ((0.001966035893636383, 12.010011201125382))
# min_function    = 0.1734831881010375
# beta0, beta1    = (0.00046847929144893, -0.21771895370478841)
# in solve_wF_vec, HF_vec = [5.55146003 5.3734311  5.25989934 5.18612557 5.13589013]
# in run_regression, HF_vec: [5.55146003 5.3734311  5.25989934 5.18612557 5.13589013]
# alpha, sigma    = ((0.0019700184269785584, 12.010003979437847))
# min_function    = 0.17348320469679562
# beta0, beta1    = (0.00046847019530892964, -0.21771899332188863)
# in solve_wF_vec, HF_vec = [5.55146055 5.37343109 5.2599003  5.18612639 5.13589252]
# in run_regression, HF_vec: [5.55146055 5.37343109 5.2599003  5.18612639 5.13589252]
# alpha, sigma    = ((0.00197201961228417, 12.010000350608221))
# min_function    = 0.17348336121990987
# beta0, beta1    = (0.0004684536900994375, -0.21771960211931426)
# namespace(alpha=0.00197201961228417, sigma=12.010000350608221)

# %%
sol = konrad.sol
par = konrad.par 

n = 100

alpha = np.linspace(0, 1, 10)
sigma = np.linspace(0,100,n)
xgrid, ygrid = np.meshgrid(alpha, sigma)
# print(xgrid)
# print(ygrid)
xy = np.stack([xgrid, ygrid])

# print(xy)
print(xgrid.ndim, ygrid.ndim, xy.ndim)

fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(xgrid, ygrid)
# Out:
# 2 2 3

# %%
def eggholder(x):
    return (-(x[1] + 47) * np.sin(np.sqrt(abs(x[0]/2 + (x[1]  + 47))))
            -x[0] * np.sin(np.sqrt(abs(x[0] - (x[1]  + 47)))))
bounds = [(-512, 512), (-512, 512)]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-512, 513)
y = np.arange(-512, 513)
xgrid, ygrid = np.meshgrid(x, y)
xy = np.stack([xgrid, ygrid])

print(xgrid.ndim, ygrid.ndim, xy.ndim)
print(xgrid.ndim, ygrid.ndim, eggholder(xy).ndim)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(45, -45)
ax.plot_surface(xgrid, ygrid, eggholder(xy), cmap='terrain')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('eggholder(x, y)')
plt.show()
# Out:
# 2 2 3
# 2 2 2
