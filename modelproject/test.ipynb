# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from scipy import optimize

# plotting
import matplotlib.pyplot as plt
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
plt.rcParams.update({'font.size': 14})

# models
from modelproject import Solow
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = Solow()
# Out:
# initialising the model
# calling .setup()

# %%
model.par.simT = 400
model.par.K_init = 2
model.par.H_init = 3

ss = model.find_steady_state()

y_t = ss.y_tilde
h_t = ss.h_tilde
k_t = ss.k_tilde

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(y_t, label = r'$\tilde{y}_t$')
ax.plot(h_t, label = r'$\tilde{h}_t$')
ax.plot(k_t, label = r'$\tilde{k}_t$')
ax.legend()



# for i in [(2,3),(1,3), (3,2),(3,1)]:
#     model.par.K_init = i[0]
#     model.par.H_init = i[1]

#     ss = model.find_steady_state(0.07,0.12)

#     y_t = ss.y_tilde
#     h_t = ss.h_tilde
#     k_t = ss.k_tilde
    
#     fig = plt.figure()
#     ax = fig.add_subplot(1,1,1)
#     ax.plot(y_t, label = r'$\tilde{y}_t$')
#     ax.plot(h_t, label = r'$\tilde{h}_t$')
#     ax.plot(k_t, label = r'$\tilde{k}_t$')
#     ax.legend()
